# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
from sklearn.naive_bayes import GaussianNB

# %%
heart_data = pd.read_csv('heart_disease_data_augmented.csv')
heart_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 heart_data = pd.read_csv('heart_disease_data_augmented.csv')
#       2 heart_data.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
heart_data.tail()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 30295   57    0   0       140   241    0        1      123      1      0.2
# 30296   45    1   3       110   264    0        1      132      0      1.2
# 30297   68    1   0       144   193    1        1      141      0      3.4
# 30298   57    1   0       130   131    0        1      115      1      1.2
# 30299   57    0   1       130   236    0        0      174      0      0.0
#
#        slope  ca  thal  target
# 30295      1   0     3       0
# 30296      1   0     3       0
# 30297      1   2     3       0
# 30298      1   1     3       0
# 30299      1   1     2       0

# %%
heart_data.shape
# Out:
# (30300, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30300 entries, 0 to 30299
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       30300 non-null  int64
#  1   sex       30300 non-null  int64
#  2   cp        30300 non-null  int64
#  3   trestbps  30300 non-null  int64
#  4   chol      30300 non-null  int64
#  5   fbs       30300 non-null  int64
#  6   restecg   30300 non-null  int64
#  7   thalach   30300 non-null  int64
#  8   exang     30300 non-null  int64
#  9   oldpeak   30300 non-null  float64
#  10  slope     30300 non-null  int64
#  11  ca        30300 non-null  int64
#  12  thal      30300 non-null  int64
#  13  target    30300 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 3.2 MB

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.describe()
# Out:
#                 age           sex            cp      trestbps          chol  \
# count  30300.000000  30300.000000  30300.000000  30300.000000  30300.000000
# mean      54.366337      0.683168      0.966997    131.623762    246.264026
# std        9.067251      0.465249      1.030365     17.509467     51.746005
# min       29.000000      0.000000      0.000000     94.000000    126.000000
# 25%       47.000000      0.000000      0.000000    120.000000    211.000000
# 50%       55.000000      1.000000      1.000000    130.000000    240.000000
# 75%       61.000000      1.000000      2.000000    140.000000    275.000000
# max       77.000000      1.000000      3.000000    200.000000    564.000000
#
#                 fbs       restecg       thalach         exang       oldpeak  \
# count  30300.000000  30300.000000  30300.000000  30300.000000  30300.000000
# mean       0.148515      0.528053    149.646865      0.326733      1.039604
# ...

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    16500
# 0    13800
# Name: count, dtype: int64

# %% [markdown]
# 1 -> Defective Heart
#
# 0 -> Healthy Heart

# %%
X = heart_data.drop(columns=['target', 'trestbps', 'fbs', 'restecg', 'thalach','exang', 'oldpeak','slope','ca','thal'], axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#        age  sex  cp  chol
# 0       63    1   3   233
# 1       37    1   2   250
# 2       41    0   1   204
# 3       56    1   1   236
# 4       57    0   0   354
# ...    ...  ...  ..   ...
# 30295   57    0   0   241
# 30296   45    1   3   264
# 30297   68    1   0   193
# 30298   57    1   0   131
# 30299   57    0   1   236
#
# [30300 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 30295    0
# 30296    0
# 30297    0
# 30298    0
# 30299    0
# Name: target, Length: 30300, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (30300, 4) (24240, 4) (6060, 4)

# %% [markdown]
# Model Training

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# model = RandomForestClassifier()
# model.fit(X_train, y_train)
# model = GaussianNB()
# model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('Accuracy on training data', training_data_accuracy)
# Out:
# Accuracy on training data 0.7523514851485148

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print("Accuracy on Test data: ",testing_data_accuracy)
# Out:
# Accuracy on Test data:  0.752970297029703

# %% [markdown]
# Building a Predictive System

# %%
input_data = (63, 1, 3, 233)

#change the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)
# print(prediction)

if(prediction == 0):
    print('The Person does not have Heart Disease')
    
else:
    print("The Person has Heart disease")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 9
#       6 #reshape the numpy array as we are predicting for only on instance
#       7 input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)
# ----> 9 prediction = model.predict(input_data_reshaped)
#      10 # print(prediction)
#      12 if(prediction == 0):
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:382, in LinearClassifierMixin.predict(self, X)
#     368 """
#     369 Predict class labels for samples in X.
#     370
#    (...)
#     379     Vector containing the class labels for each sample.
#     380 """
#     381 xp, _ = get_namespace(X)
# ...

# %%
import joblib

# Save the model
joblib.dump(model, 'heartpred.pkl')
# Out:
# ['heartpred.pkl']
